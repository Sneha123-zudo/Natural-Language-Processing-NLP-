# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha123-zudo/Natural-Language-Processing-NLP-/blob/main/Regex_NLP_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGEX IN CUSTOMER SUPPORT**

# %% [markdown]
# 1. Retrieve Order Number

# %%
import re

# %%
chat1='codebasics: Hello, I am having an issue with my order # 412889912'

# %%
pattern = 'order[^\d]*[\d]*'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3466410677.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'order[^\d]*[\d]*'

# %%
matches = re.findall(pattern,chat1)
matches
# Out:
# ['order # 412889912']

# %%
pattern2 = 'order[^\d]*([\d]*)'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2159547823.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern2 = 'order[^\d]*([\d]*)'

# %%
matches = re.findall(pattern2, chat1)
matches
# Out:
# ['412889912']

# %% [markdown]
# 2. Retrieve email_id and phone number

# %%
chat = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com ,codebasics: here it is: (123)-567-8912, abc@xyz.com , codebasics: yes, phone: 1235678912 email: abc@xyz.com'

# %% [markdown]
# Phone Number

# %%
pattern = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-338910762.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'

# %%
matches = re.findall(pattern,chat)
matches
# Out:
# ['1235678912', '(123)-567-8912', '1235678912']

# %% [markdown]
# EmailID

# %%
pattern = '[a-zA-z]*@[a-zA-z]*\.[a-zA-z]*'
matches = re.findall(pattern,chat)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-2145422905.py:1: SyntaxWarning: invalid escape sequence '\.'
#   pattern = '[a-zA-z]*@[a-zA-z]*\.[a-zA-z]*'
# ['abc@xyz.com', 'abc@xyz.com', 'abc@xyz.com']

# %% [markdown]
# **REGEX for Information Extraction**

# %%
text='''
Born	Elon Reeve Musk
June 28, 1971 (age 50)
Pretoria, Transvaal, South Africa
Citizenship
South Africa (1971–present)
Canada (1971–present)
United States (2002–present)
Education	University of Pennsylvania (BS, BA)
Title
Founder, CEO and Chief Engineer of SpaceX
CEO and product architect of Tesla, Inc.
Founder of The Boring Company and X.com (now part of PayPal)
Co-founder of Neuralink, OpenAI, and Zip2
Spouse(s)
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2012)​
​
​(m. 2013; div. 2016)
'''

# %% [markdown]
# 1. Age

# %%
pattern = '(age \d+)'
pattern1 = '(age (\d+))'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3957977012.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '(age \d+)'
# /tmp/ipython-input-3957977012.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern1 = '(age (\d+))'

# %%
matches = re.findall(pattern,text)
matches1 = re.findall(pattern1,text)
matches
matches1
# Out:
# [('age 50', '50')]

# %%
pattern2 = 'Born(.*)'
matches = re.findall(pattern2,text)
matches
# Out:
# ['\tElon Reeve Musk']

# %%
pattern3='Born.*\n(.*)\(age'
matches = re.findall(pattern3,text)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-3179664055.py:1: SyntaxWarning: invalid escape sequence '\('
#   pattern3='Born.*\n(.*)\(age'
# ['June 28, 1971 ']

# %%
pattern4 = '\(age.*\n(.*)'
matches = re.findall(pattern4, text)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-2831191373.py:1: SyntaxWarning: invalid escape sequence '\('
#   pattern4 = '\(age.*\n(.*)'
# ['Pretoria, Transvaal, South Africa']

# %%
import re

def get_pattern_match(pattern, text, group_idx=1):
    """
    Finds the first match of a regex pattern in the given text and returns
    the content of the specified capturing group.
    Uses re.DOTALL flag to allow '.' to match newlines.
    """
    match = re.search(pattern, text, re.DOTALL)
    if match:
        try:
            return match.group(group_idx)
        except IndexError:
            # If the requested group_idx does not exist, return the entire match
            return match.group(0)
    return None

def extract_personal_information(text):
    age_str = get_pattern_match(r'age (\d+)', text)
    full_name = get_pattern_match(r'Born(.*)\n', text)
    birth_date = get_pattern_match(r'Born.*\n(.*)\(age', text)
    birth_place = get_pattern_match(r'\(age.*\n(.*)', text)

    return {
        'age': int(age_str) if age_str else None,
        'name': full_name.strip() if full_name else None,
        'birth_date': birth_date.strip() if birth_date else None,
        'birth_place': birth_place.strip() if birth_place else None
    }

# %%
extract_personal_information(text)
# Out:
# {'age': 50,
#  'name': 'Elon Reeve Musk\nJune 28, 1971 (age 50)\nPretoria, Transvaal, South Africa\nCitizenship\t\nSouth Africa (1971–present)\nCanada (1971–present)\nUnited States (2002–present)\nEducation\tUniversity of Pennsylvania (BS, BA)\nTitle\t\nFounder, CEO and Chief Engineer of SpaceX\nCEO and product architect of Tesla, Inc.\nFounder of The Boring Company and X.com (now part of PayPal)\nCo-founder of Neuralink, OpenAI, and Zip2\nSpouse(s)\t\nJustine Wilson\n\u200b\n\u200b(m. 2000; div. 2008)\u200b\nTalulah Riley\n\u200b\n\u200b(m. 2010; div. 2012)\u200b\n\u200b\n\u200b(m. 2013; div. 2016)',
#  'birth_date': 'June 28, 1971',
#  'birth_place': None}

# %% [markdown]
# **Exercise - Python Regular Expression Tutorial Exericse**

# %% [markdown]
# 1.. Extract all twitter handles from following text. Twitter handle is the text that appears after https://twitter.com/ and is a single word. Also it contains only alpha numeric characters i.e. A-Z a-z , o to 9 and underscore _

# %%
text = '''
Follow our leader Elon musk on twitter here: https://twitter.com/elonmusk, more information
on Tesla's products can be found at https://www.tesla.com/. Also here are leading influencers
for tesla related news,
https://twitter.com/teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla
'''
pattern = 'https://twitter\.com/([a-zA-Z0-9_]+)'

re.findall(pattern, text)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-221284837.py:9: SyntaxWarning: invalid escape sequence '\.'
#   pattern = 'https://twitter\.com/([a-zA-Z0-9_]+)'
# ['elonmusk', 'teslarati', 'dummy_tesla', 'dummy_2_tesla']

# %% [markdown]
# 2. Extract Concentration Risk Types. It will be a text that appears after "Concentration Risk:", In below example, your regex should extract these two strings
#
# (1) Credit Risk
#
# (2) Supply Rish

# %%
text = '''
Concentration of Risk: Credit Risk
Financial instruments that potentially subject us to a concentration of credit risk consist of cash, cash equivalents, marketable securities,
restricted cash, accounts receivable, convertible note hedges, and interest rate swaps. Our cash balances are primarily invested in money market funds
or on deposit at high credit quality financial institutions in the U.S. These deposits are typically in excess of insured limits. As of September 30, 2021
and December 31, 2020, no entity represented 10% or more of our total accounts receivable balance. The risk of concentration for our convertible note
hedges and interest rate swaps is mitigated by transacting with several highly-rated multinational banks.
Concentration of Risk: Supply Risk
We are dependent on our suppliers, including single source suppliers, and the inability of these suppliers to deliver necessary components of our
products in a timely manner at prices, quality levels and volumes acceptable to us, or our inability to efficiently manage these components from these
suppliers, could have a material adverse effect on our business, prospects, financial condition and operating results.
'''
pattern = 'Concentration of Risk: ([^\n.]*)'

re.findall(pattern, text)
# Out:
# ['Credit Risk', 'Supply Risk']

# %% [markdown]
# 3. Companies in europe reports their financial numbers of semi annual basis and you can have a document like this. To exatract quarterly and semin annual period you can use a regex as shown below
#
# Hint: you need to use (?:) here to match everything enclosed

# %%
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion.
BMW's gross cost of operating vehicles in FY2021 S1 was $8 billion.
'''

pattern = 'FY(\d{4} [A-z]*\d)'
matches = re.findall(pattern, text)
matches
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1146840324.py:6: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'FY(\d{4} [A-z]*\d)'
# ['2021 Q1', '2021 S1']

# %%
pattern2='FY(\d{4} (?:Q[1-4]|S[1-2]))'
matches = re.findall(pattern2, text)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3756503405.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern2='FY(\d{4} (?:Q[1-4]|S[1-2]))'
# ['2021 Q1', '2021 S1']
